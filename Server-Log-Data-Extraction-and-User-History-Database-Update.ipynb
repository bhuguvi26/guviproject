# %% [markdown]
# <a href="https://colab.research.google.com/github/bhuguvi26/Server-Log-Data-Extraction-and-User-History-Database-Update/blob/main/Server-Log-Data-Extraction-and-User-History-Database-Update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
#  Google Colab – Email ETL (Auto-Fetch GitHub Raw File)
#  Includes all 10 SQL queries
# ============================================================

# !pip install -q pymongo dnspython

import os, re, sqlite3, sys
from datetime import datetime
from pymongo import MongoClient

# ---------------- CONFIG ----------------
RAW_URL = "https://raw.githubusercontent.com/bhuguvi26/Server-Log-Data-Extraction-and-User-History-Database-Update/refs/heads/main/mbox.txt"
LOG_FILE = "/content/mbox.txt"

MONGO_URI = "mongodb+srv://testuser:testuser@cluster0.obh30fm.mongodb.net/?appName=Cluster0"
MONGO_DB = "server_logs"
MONGO_COLLECTION = "user_history"
SQLITE_DB = "/content/user_history.db"

# ---------------- STEP 1: Auto-Download Log File ----------------
print("\n🌐 Downloading 'mbox.txt' from GitHub...")
os.system(f"wget -q -O {LOG_FILE} {RAW_URL}")
print("✅ File downloaded.\n")

# ---------------- STEP 2: Extract Data ----------------
def extract_email_date(filepath):
    print("🔍 Extracting email addresses and dates...")
    from_pattern = re.compile(r'^From\s+([\w\.-]+@[\w\.-]+)\s+(.*)')

    data, seen = [], set()

    with open(filepath, encoding="utf-8", errors="ignore") as f:
        for line in f:
            line = line.strip()
            m = from_pattern.match(line)
            if m:
                email, datestr = m.group(1), m.group(2)

                # Try common date formats
                dt = None
                for fmt in ["%a %b %d %H:%M:%S %Y", "%a %b %d %H:%M:%S %z %Y"]:
                    try:
                        dt = datetime.strptime(datestr, fmt)
                        break
                    except:
                        pass

                if dt:
                    formatted_date = dt.strftime("%Y-%m-%d %H:%M:%S")
                    key = (email, formatted_date)

                    if key not in seen:
                        seen.add(key)
                        data.append({"email": email, "date": formatted_date})

    print(f"✅ Extracted {len(data)} records.\n")
    return data

extracted = extract_email_date(LOG_FILE)
if not extracted:
    sys.exit("❌ No records found — check your mbox.txt file!")

# ---------------- STEP 3: Upload to MongoDB ----------------
def upload_to_mongo(data):
    print("🌐 Connecting to MongoDB...")
    try:
        client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=5000)
        client.admin.command("ping")
        print("✅ Connection successful.")

        db = client[MONGO_DB]
        col = db[MONGO_COLLECTION]

        col.delete_many({})
        col.insert_many(data)

        print(f"✅ Uploaded {len(data)} documents.\n")
        return True
    except Exception as e:
        print(f"⚠ Mongo upload failed: {e}")
        return False

mongo_ok = upload_to_mongo(extracted)

# ---------------- STEP 4: Fetch from MongoDB ----------------
def fetch_from_mongo():
    print("📥 Fetching from MongoDB...")
    try:
        client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=5000)
        db = client[MONGO_DB]
        col = db[MONGO_COLLECTION]
        recs = list(col.find({}, {"_id": 0}))
        print(f"✅ Fetched {len(recs)} records.\n")
        return recs
    except Exception as e:
        print(f"⚠ Fetch failed: {e}")
        return []

records = fetch_from_mongo() if mongo_ok else extracted

# ---------------- STEP 5: Save to SQLite ----------------
def save_to_sqlite(records):
    print("💾 Saving to SQLite...")

    conn = sqlite3.connect(SQLITE_DB)
    cur = conn.cursor()

    cur.execute("""
        CREATE TABLE IF NOT EXISTS user_history (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            email TEXT NOT NULL,
            date TEXT NOT NULL
        );
    """)

    cur.executemany(
        "INSERT INTO user_history (email, date) VALUES (?, ?)",
        [(r["email"], r["date"]) for r in records]
    )

    conn.commit()
    conn.close()
    print("✅ Data saved to SQLite.\n")

save_to_sqlite(records)

# ---------------- STEP 6: Run All 10 SQL Queries ----------------
def run_sql_queries():
    print("📊 Running SQL Analysis...\n")
    conn = sqlite3.connect(SQLITE_DB)
    cur = conn.cursor()

    queries = {
        "1️⃣ Unique emails": "SELECT COUNT(DISTINCT email) FROM user_history;",
        "2️⃣ Emails per day": "SELECT DATE(date), COUNT(*) FROM user_history GROUP BY DATE(date);",
        "3️⃣ First email per address": "SELECT email, MIN(date) FROM user_history GROUP BY email;",
        "4️⃣ Last email per address": "SELECT email, MAX(date) FROM user_history GROUP BY email;",
        "5️⃣ Total emails": "SELECT COUNT(*) FROM user_history;",
        "6️⃣ Emails per month": "SELECT strftime('%Y-%m', date), COUNT(*) FROM user_history GROUP BY 1;",
        "7️⃣ Most active email": "SELECT email, COUNT(*) AS cnt FROM user_history GROUP BY email ORDER BY cnt DESC LIMIT 1;",
        "8️⃣ Domain counts": """
            SELECT SUBSTR(email, INSTR(email,'@')+1) AS domain, COUNT(*)
            FROM user_history GROUP BY domain ORDER BY COUNT(*) DESC;
        """,
        "9️⃣ First appearance of each domain": """
            SELECT SUBSTR(email, INSTR(email,'@')+1) AS domain, MIN(date)
            FROM user_history GROUP BY domain;
        """,
        "🔟 Oldest 5 emails": "SELECT email, date FROM user_history ORDER BY date ASC LIMIT 5;"
    }

    for title, q in queries.items():
        print(f"➡️ {title}")
        cur.execute(q)
        for row in cur.fetchall():
            print(row)
        print("-" * 40)

    conn.close()
    print("\n✅ SQL analysis completed.\n")

run_sql_queries()

print("🎉 Pipeline Completed Successfully (No DB download required).")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 60.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 106.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 84.3 MB/s eta 0:00:00
# == Missing data BEFORE (%) ==
# District code                    0.00
# State_UT                         0.00
# District                         0.00
# Population                       4.69
# Male                             4.69
#                                  ...
# Power_Parity_Rs_330000_425000    5.16
# Power_Parity_Rs_425000_545000    4.69
# Power_Parity_Rs_330000_545000    3.59
# Power_Parity_Above_Rs_545000     4.69
# Total_Power_Parity               5.00
# Length: 118, dtype: float64
#
# == Missing data AFTER (%) ==
# District code                    0.00
# State_UT                         0.00
# District                         0.00
# Population                       0.16
# Male                             4.69
#                                  ...
# Power_Parity_Rs_330000_425000    5.16
# Power_Parity_Rs_425000_545000    4.69
# Power_Parity_Rs_330000_545000    3.59
# Power_Parity_Above_Rs_545000     4.69
# Total_Power_Parity               5.00
# Length: 118, dtype: float64
#
# == Sample of processed data ==
#    District code           State_UT     District  Population      Male  \
# 0              1  Jammu and Kashmir      Kupwara    870354.0  474190.0
# 1              2  Jammu and Kashmir       Badgam    753745.0       NaN
# 2              3  Jammu and Kashmir  Leh(Ladakh)    133487.0   78971.0
# 3              4             Ladakh       Kargil    140802.0       NaN
# 4              5  Jammu and Kashmir        Punch    476835.0  251899.0
#
#      Female  Literate  Literate_Male  Literate_Female      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0   86236.0        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# 1                         126.0                         562.0
# 2                          46.0                         122.0
# 3                          27.0                         114.0
# 4                          78.0                         346.0
#
#    Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 0                           71.0                          101.0
# 1                           72.0                           89.0
# 2                           15.0                           22.0
# 3                           12.0                           18.0
# 4                           35.0                           50.0
#
#    Power_Parity_Rs_150000_330000  Power_Parity_Rs_330000_425000  \
# 0                          172.0                           74.0
# 1                          161.0                           96.0
# 2                            NaN                           20.0
# 3                           30.0                           19.0
# 4                           85.0                           59.0
#
#    Power_Parity_Rs_425000_545000  Power_Parity_Rs_330000_545000  \
# 0                           10.0                           84.0
# 1                           28.0                          124.0
# 2                            NaN                            NaN
# 3                            3.0                           22.0
# 4                            8.0                           67.0
#
#    Power_Parity_Above_Rs_545000  Total_Power_Parity
# 0                          15.0              1119.0
# 1                          18.0              1066.0
# 2                          17.0               242.0
# 3                           7.0               214.0
# 4                          12.0               629.0
#
# [5 rows x 118 columns]
# 2025-12-01 15:12:42.051 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ✅ Data uploaded to MongoDB successfully.
# ✅ Data uploaded to SQLite with dimensions and constraints.
# 2025-12-01 15:12:42.206
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-12-01 15:12:42.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.222 Session state does not function when running a script without `streamlit run`
# 2025-12-01 15:12:42.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:12:42.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3750478037.py in <cell line: 0>()
#     423
#     424 with open("app.py", "w") as f:
# --> 425     f.write(app_code)
#     426
#     427 # 4) Start Streamlit in the background (port 8501)
#
# NameError: name 'app_code' is not defined
